# %%
import requests
import time
import pandas as pd

def get_token_price_history(token_address, start_date='2022-10-01', end_date='2024-11-10', interval='15m'):
    """
    Fetch historical price data for a Solana token
    
    Args:
        token_address (str): The mint address of the token
        start_date (str): Start date in YYYY-MM-DD format
        end_date (str): End date in YYYY-MM-DD format 
        interval (str): Time interval for the data points
        
    Returns:
        pandas.DataFrame: DataFrame containing OHLCV data
    """
    from dotenv import load_dotenv
    import os
    load_dotenv()
    API_KEY = os.getenv('SOLANATRACKER_API_KEY')
    
    # API endpoint
    url = f'https://data.solanatracker.io/chart/{token_address}'

    # Query parameters
    params = {
        'type': interval,
        'time_from': int(time.mktime(time.strptime(start_date, '%Y-%m-%d'))),
        'time_to': int(time.mktime(time.strptime(end_date, '%Y-%m-%d')))
    }

    # Headers
    headers = {
        'x-api-key': API_KEY
    }

    # Send GET request
    response = requests.get(url, headers=headers, params=params)

    # Check for successful response
    if response.status_code == 200:
        data = response.json()
        df_data = []
        for entry in data['oclhv']:
            df_data.append({
                'Time': time.strftime('%Y-%m-%d %H:%M:%S', time.gmtime(entry['time'])),
                'Open': entry['open'],
                'High': entry['high'], 
                'Low': entry['low'],
                'Close': entry['close'],
                'Volume': entry['volume']
            })
        return pd.DataFrame(df_data)
    else:
        print(f"Error: {response.status_code} - {response.text}")
        return None

# %%
import requests
import pandas as pd

# Define the base URL for CoinGecko API
base_url = 'https://api.coingecko.com/api/v3'

# Step 1: Retrieve the list of categories to find the 'Solana Meme Coins' category ID
categories_url = f'{base_url}/coins/categories/list'
categories_response = requests.get(categories_url)
categories = categories_response.json()

# Find the category ID for 'Solana Meme Coins'
category_id = None
for category in categories:
    if category['name'].lower() == 'solana meme':
        category_id = category['category_id']
        break

if not category_id:
    print("Category 'Solana Meme Coins' not found.")


# Step 2: Retrieve coins in the 'Solana Meme Coins' category
coins_url = f'{base_url}/coins/markets'
params = {
    'vs_currency': 'usd',
    'category': category_id,
    'per_page': 250,  # Adjust as needed
    'page': 1
}
coins_response = requests.get(coins_url, params=params)
coins = coins_response.json()
import time
# Step 3: Retrieve contract addresses for each coin
# Out:
# dogwifhat
# Bonk
# Popcat
# Goatseus Maximus
# cat in a dogs world
# Gigachad
# BOOK OF MEME
# Fwog
# Moo Deng
# PONKE
# michi
# RETARDIO
# MUMU THE BULL
# Sigma
# Peanut the Squirrel
# LOCK IN
# Myro
# Wen
# Slerf
# MANEKI
# Luce
# Smoking Chicken Fish
# Fartcoin
# Daddy Tate
# We Love T
# Mother Iggy
# SelfieDogCoin
# mini
# Skibidi Toilet
# Harambe on Solana
# Zerebro
# Dolan Duck
# McDull (Meme)
# Rich Quack
# ai16z
# Giko Cat
# aura
# KOALA AI
# Samoyedcoin
# Comedian
# Billy
# Brainlet
# GME
# Act I The AI Prophecy
# Monkey Pox
# earl
# Sillynubcat
# Nailong
# Effective accelerationism
# American Coin
# Chudjak
# Shark Cat
# SAD HAMSTER
# Ginnan The Cat
# NPC On Solana
# Manifest
# Kitten Haimer
# Aiwithdaddyissues
# Solama
# Peng
# hehe
# TEH EPIK DUCK
# the Soldog
# Boba Oppa
# Milady Wif Hat
# Habibi (Sol)
# Memes AI
# catwifhat
# Bozo Benk
# coby
# suwi
# Rawr
# LandWolf
# Doland Tremp
# Ben the Dog
# RNT
# Catcoin
# DUKO
# Omega
# Rocky
# Shoggoth
# SNAP
# Gotti Token
# 360noscope420blazeit
# Slothana
# tooker kurlson
# Puffy
# Toad (SOL)
# catownkimono
# Beercoin
# autism
# LUCI
# MAD
# brainrot
# Waffles
# nomnom
# LOL
# Hege
# supercycle(real)
# littlemanyu
# GUMMY
# ORC
# HeeeHeee
# Literally Me
# r/snoofi
# Cost Hot Dog
# RIBBIT
# BUU
# monkeyhaircut
# EnKrypto
# Pundu
# TabMan
# POPDOG
# Alpha
# Sharbi
# Melon Dog
# Let Him Cook
# BitCat
# Look bro
# TORSY
# LFGO
# Degen Spartan AI
# Neiro
# Guacamole
# Honk
# Wrapped DOG
# Numogram
# POUPE
# Dark MAGA
# New Born Haggis Pygmy Hippo
# Bingus The Cat
# First Convicted RACCON
# Smilek
# analoS
# MILKBAG
# chaos and disorder
# LOAFCAT
# Neiro
# Tate Terminal
# COAL
# The RugCoon
# Tori the Cat
# Uranus
# BOGUS
# Morud
# Zoomer
# Floos
# Believe In Something
# Zack Morris
# iiii lovvvv youuuu
# el gato
# Meme Coin Millionaire
# Sage Universe
# Doug the Duck
# CLAPCAT
# Banana Tape Wall
# real.
# IQ50
# CryptoBoomCoin Official
# Hund
# Market Dominance
# PINO
# Pepe on SOL
# GMika
# Eagle of Truth
# BASED
# Cheese
# Pigeon Tech
# Autonomous Virtual Beings
# VENKO
# Sharki
# Harold
# President.exe
# catwifbag
# Send
# FECES
# The Ticker Is ETH
# Moth
# WAWA CAT
# DOGAI
# doginthpool
# Half Orange Drinking Lemonade
# MEN
# peanie
# Lolcat
# Pajamas Cat
# HAMI
# MoonScape
# tuki
# CCTV
# FATGF
# Pesto the Baby King Penguin
# Low Quality Cat
# The Professor
# BarbieCrashBandicootRFK88
# Blinks.gg
# AI Crystal Node
# Crashout
# DollarMoon
# Cat-Dog
# Noooomeme
# John the Coin
# Gemini
# Dog Emoji On Solana
# Naked Jim
# DoginHood
# Dasha
# INU
# WATER Coin
# Doge Jones Industrial Average
# Cheeseball
# Top Hat
# Bork
# Anita Max Wynn
# Pochita
# Dollar
# Smiling Dolphin
# Jeo Boden
# Success Kid
# neversol
# ADA
# MIMANY
# Bet more
# PSYOP
# DOGE on Solana
# Pepe Trump
# Aquarius
# WHISKEY
# RETARDIA
# Gooby
# Taurus
# What’s Updog?
# Cancer
# Sagittarius
# Keyboard Cat
# Leo
# infinite backrooms
# Slop
# PONK
# Aries
# Soyjak
# Malakai
# Capricorn
# Cheems
# Pisces
# kittyspin
# Gecko (Meme)
# Libra
# todd
# Scorpio
#                     Coin   Symbol  \
# 0              dogwifhat      wif
# 1                   Bonk     bonk
# 2                 Popcat   popcat
# 3       Goatseus Maximus     goat
# 4    cat in a dogs world      mew
# ..                   ...      ...
# 245            kittyspin       ks
# 246         Gecko (Meme)    gecko
# 247                Libra    libra
# 248                 todd     todd
# 249              Scorpio  scorpio
#
#                                  Contract Address
# 0    EKpQGSJtjMFqKZ9KQanSqYXRcF8fBopzLHYxdM65zcjm
# 1    DezXAZ8z7PnrnRJjz3wXBoRgixCa6xjnB7YaB1pPB263
# 2    7GCihgDB8fe6KNjn2MYtkzZcRjQy3t9GHdC8uHYmW2hr
# 3                                            None
# 4                                            None
# ..                                            ...
# 245                                          None
# 246                                          None
# 247                                          None
# 248                                          None
# 249                                          None
#
# [250 rows x 3 columns]

# %%
data = []
for coin in coins:
    if coin['name'] not in [d['Coin'] for d in data]:
        print(coin['name'])
        coin_id = coin['id']
        coin_detail_url = f'{base_url}/coins/{coin_id}'
        coin_detail_response = requests.get(coin_detail_url)
        while coin_detail_response.status_code != 200:
            time.sleep(15)
            coin_detail_response = requests.get(coin_detail_url)
            print('error')
        coin_detail = coin_detail_response.json()

        # Extract contract address on Solana platform
        contract_address = coin_detail.get('platforms', {}).get('solana')
        data.append({
            'Coin': coin['name'],
            'Symbol': coin['symbol'],
            'Contract Address': contract_address
        })
        time.sleep(3)
        print(f'{coin["name"]} done')
    else:
        print(f'Skipping {coin["name"]} - already processed')

# Create DataFrame
df = pd.DataFrame(data)
print(df)
# Out:
# Skipping dogwifhat - already processed
# Skipping Bonk - already processed
# Skipping Popcat - already processed
# Skipping Goatseus Maximus - already processed
# Skipping cat in a dogs world - already processed
# Skipping Gigachad - already processed
# Skipping BOOK OF MEME - already processed
# Skipping Fwog - already processed
# Skipping Moo Deng - already processed
# Skipping PONKE - already processed
# Skipping michi - already processed
# Skipping RETARDIO - already processed
# Skipping MUMU THE BULL - already processed
# Skipping Sigma - already processed
# Skipping Peanut the Squirrel - already processed
# Skipping LOCK IN - already processed
# Skipping Myro - already processed
# Skipping Wen - already processed
# Skipping Slerf - already processed
# Skipping MANEKI - already processed
# Skipping Luce - already processed
# Skipping Smoking Chicken Fish - already processed
# Skipping Fartcoin - already processed
# Skipping Daddy Tate - already processed
# Skipping We Love T - already processed
# Skipping Mother Iggy - already processed
# Skipping SelfieDogCoin - already processed
# Skipping mini - already processed
# Skipping Skibidi Toilet - already processed
# Skipping Harambe on Solana - already processed
# Skipping Zerebro - already processed
# Skipping Dolan Duck - already processed
# Skipping McDull (Meme) - already processed
# Skipping Rich Quack - already processed
# Skipping ai16z - already processed
# Skipping Giko Cat - already processed
# Skipping aura - already processed
# Skipping KOALA AI - already processed
# Skipping Samoyedcoin - already processed
# Skipping Comedian - already processed
# Skipping Billy - already processed
# Skipping Brainlet - already processed
# Skipping GME - already processed
# Skipping Act I The AI Prophecy - already processed
# Skipping Monkey Pox - already processed
# Skipping earl - already processed
# Skipping Sillynubcat - already processed
# Skipping Nailong - already processed
# Skipping Effective accelerationism - already processed
# Skipping American Coin - already processed
# Skipping Chudjak - already processed
# Skipping Shark Cat - already processed
# Skipping SAD HAMSTER - already processed
# Skipping Ginnan The Cat - already processed
# Skipping NPC On Solana - already processed
# Skipping Manifest - already processed
# Skipping Kitten Haimer - already processed
# Skipping Aiwithdaddyissues - already processed
# Skipping Solama - already processed
# Skipping Peng - already processed
# Skipping hehe - already processed
# Skipping TEH EPIK DUCK - already processed
# Skipping the Soldog - already processed
# Skipping Boba Oppa - already processed
# Skipping Milady Wif Hat - already processed
# Skipping Habibi (Sol) - already processed
# Skipping Memes AI - already processed
# Skipping catwifhat - already processed
# Skipping Bozo Benk - already processed
# Skipping coby - already processed
# Skipping suwi - already processed
# Skipping Rawr - already processed
# Skipping LandWolf - already processed
# Skipping Doland Tremp - already processed
# Skipping Ben the Dog - already processed
# Skipping RNT - already processed
# Skipping Catcoin - already processed
# Skipping DUKO - already processed
# Skipping Omega - already processed
# Skipping Rocky - already processed
# Skipping Shoggoth - already processed
# Skipping SNAP - already processed
# Skipping Gotti Token - already processed
# Skipping 360noscope420blazeit - already processed
# Skipping Slothana - already processed
# Skipping tooker kurlson - already processed
# Skipping Puffy - already processed
# Skipping Toad (SOL) - already processed
# Skipping catownkimono - already processed
# Skipping Beercoin - already processed
# Skipping autism - already processed
# Skipping LUCI - already processed
# Skipping MAD - already processed
# Skipping brainrot - already processed
# Skipping Waffles - already processed
# Skipping nomnom - already processed
# Skipping LOL - already processed
# Skipping Hege - already processed
# Skipping supercycle(real) - already processed
# Skipping littlemanyu - already processed
# Skipping GUMMY - already processed
# Skipping ORC - already processed
# Skipping HeeeHeee - already processed
# Literally Me
# Literally Me done
# r/snoofi
# r/snoofi done
# Cost Hot Dog
# Cost Hot Dog done
# RIBBIT
# RIBBIT done
# BUU
# BUU done
# monkeyhaircut
# monkeyhaircut done
# EnKrypto
# error
# error
# error
# error
# EnKrypto done
# Pundu
# Pundu done
# TabMan
# TabMan done
# POPDOG
# error
# error
# error
# error
# POPDOG done
# Alpha
# Alpha done
# Sharbi
# Sharbi done
# Melon Dog
# Melon Dog done
# Let Him Cook
# Let Him Cook done
# BitCat
# error
# error
# error
# error
# BitCat done
# Look bro
# Look bro done
# TORSY
# TORSY done
# LFGO
# LFGO done
# Degen Spartan AI
# Degen Spartan AI done
# Neiro
# Neiro done
# Guacamole
# error
# error
# error
# error
# Guacamole done
# Honk
# Honk done
# Wrapped DOG
# Wrapped DOG done
# Numogram
# Numogram done
# POUPE
# error
# error
# error
# error
# POUPE done
# Dark MAGA
# Dark MAGA done
# New Born Haggis Pygmy Hippo
# New Born Haggis Pygmy Hippo done
# Bingus The Cat
# Bingus The Cat done
# First Convicted RACCON
# error
# error
# error
# error
# First Convicted RACCON done
# Smilek
# Smilek done
# analoS
# analoS done
# MILKBAG
# MILKBAG done
# chaos and disorder
# chaos and disorder done
# LOAFCAT
# error
# error
# error
# error
# LOAFCAT done
# Skipping Neiro - already processed
# Tate Terminal
# Tate Terminal done
# COAL
# COAL done
# The RugCoon
# The RugCoon done
# Tori the Cat
# Tori the Cat done
# Uranus
# Uranus done
# BOGUS
# error
# error
# error
# error
# BOGUS done
# Morud
# Morud done
# Zoomer
# Zoomer done
# Floos
# Floos done
# Believe In Something
# error
# error
# error
# error
# Believe In Something done
# Zack Morris
# Zack Morris done
# iiii lovvvv youuuu
# iiii lovvvv youuuu done
# el gato
# el gato done
# Meme Coin Millionaire
# error
# error
# error
# error
# Meme Coin Millionaire done
# Sage Universe
# Sage Universe done
# Doug the Duck
# Doug the Duck done
# CLAPCAT
# CLAPCAT done
# Banana Tape Wall
# Banana Tape Wall done
# real.
# error
# error
# error
# error
# real. done
# IQ50
# IQ50 done
# CryptoBoomCoin Official
# CryptoBoomCoin Official done
# Hund
# Hund done
# Market Dominance
# Market Dominance done
# PINO
# PINO done
# Pepe on SOL
# error
# error
# error
# error
# Pepe on SOL done
# GMika
# GMika done
# Eagle of Truth
# Eagle of Truth done
# BASED
# error
# error
# error
# error
# BASED done
# Cheese
# Cheese done
# Pigeon Tech
# Pigeon Tech done
# Autonomous Virtual Beings
# Autonomous Virtual Beings done
# VENKO
# VENKO done
# Sharki
# error
# error
# error
# error
# Sharki done
# Harold
# Harold done
# President.exe
# President.exe done
# catwifbag
# catwifbag done
# Send
# Send done
# FECES
# FECES done
# The Ticker Is ETH
# error
# error
# error
# error
# The Ticker Is ETH done
# Moth
# Moth done
# WAWA CAT
# WAWA CAT done
# DOGAI
# DOGAI done
# doginthpool
# error
# error
# error
# error
# doginthpool done
# Half Orange Drinking Lemonade
# Half Orange Drinking Lemonade done
# MEN
# MEN done
# peanie
# peanie done
# Lolcat
# error
# error
# error
# error
# Lolcat done
# Pajamas Cat
# Pajamas Cat done
# HAMI
# HAMI done
# MoonScape
# MoonScape done
# tuki
# tuki done
# CCTV
# error
# error
# error
# error
# CCTV done
# FATGF
# FATGF done
# Pesto the Baby King Penguin
# Pesto the Baby King Penguin done
# Low Quality Cat
# Low Quality Cat done
# The Professor
# The Professor done
# BarbieCrashBandicootRFK88
# BarbieCrashBandicootRFK88 done
# Blinks.gg
# error
# error
# error
# error
# Blinks.gg done
# AI Crystal Node
# AI Crystal Node done
# Crashout
# Crashout done
# DollarMoon
# error
# error
# error
# error
# DollarMoon done
# Cat-Dog
# Cat-Dog done
# Noooomeme
# Noooomeme done
# John the Coin
# John the Coin done
# Gemini
# error
# error
# error
# error
# Gemini done
# Dog Emoji On Solana
# Dog Emoji On Solana done
# Naked Jim
# Naked Jim done
# DoginHood
# DoginHood done
# Dasha
# Dasha done
# INU
# error
# error
# error
# error
# INU done
# WATER Coin
# WATER Coin done
# Doge Jones Industrial Average
# Doge Jones Industrial Average done
# Cheeseball
# Cheeseball done
# Top Hat
# Top Hat done
# Bork
# Bork done
# Anita Max Wynn
# error
# error
# error
# error
# Anita Max Wynn done
# Pochita
# Pochita done
# Dollar
# Dollar done
# Smiling Dolphin
# error
# error
# error
# error
# Smiling Dolphin done
# Jeo Boden
# Jeo Boden done
# Success Kid
# Success Kid done
# neversol
# neversol done
# ADA
# ADA done
# MIMANY
# error
# error
# error
# error
# MIMANY done
# Bet more
# Bet more done
# PSYOP
# PSYOP done
# DOGE on Solana
# DOGE on Solana done
# Pepe Trump
# Pepe Trump done
# Aquarius
# Aquarius done
# WHISKEY
# error
# error
# error
# error
# WHISKEY done
# RETARDIA
# RETARDIA done
# Gooby
# Gooby done
# Taurus
# Taurus done
# What’s Updog?
# What’s Updog? done
# Cancer
# error
# error
# error
# error
# Cancer done
# Sagittarius
# Sagittarius done
# Keyboard Cat
# Keyboard Cat done
# Leo
# error
# error
# error
# error
# Leo done
# infinite backrooms
# infinite backrooms done
# Slop
# Slop done
# PONK
# PONK done
# Aries
# Aries done
# Soyjak
# error
# error
# error
# error
# Soyjak done
# Malakai
# Malakai done
# Capricorn
# Capricorn done
# Cheems
# Cheems done
# Pisces
# Pisces done
# kittyspin
# kittyspin done
# Gecko (Meme)
# error
# error
# error
# error
# Gecko (Meme) done
# Libra
# Libra done
# todd
# todd done
# Scorpio
# Scorpio done
#                     Coin   Symbol  \
# 0              dogwifhat      wif
# 1                   Bonk     bonk
# 2                 Popcat   popcat
# 3       Goatseus Maximus     goat
# 4    cat in a dogs world      mew
# ..                   ...      ...
# 244            kittyspin       ks
# 245         Gecko (Meme)    gecko
# 246                Libra    libra
# 247                 todd     todd
# 248              Scorpio  scorpio
#
#                                  Contract Address
# 0    EKpQGSJtjMFqKZ9KQanSqYXRcF8fBopzLHYxdM65zcjm
# 1    DezXAZ8z7PnrnRJjz3wXBoRgixCa6xjnB7YaB1pPB263
# 2    7GCihgDB8fe6KNjn2MYtkzZcRjQy3t9GHdC8uHYmW2hr
# 3    CzLSujWBLFsSjncfkh59rUFqvafWcY5tzedWJSuypump
# 4     MEW1gQWJ3nEXg2qgERiKu7FAFj79PHvQVREQUzScPP5
# ..                                            ...
# 244  72LTryHMb1m9j4NEcn673sXkFMXMmHvmB8grYcVspump
# 245  6CNHDCzD5RkvBWxxyokQQNQPjFWgoHF94D7BmC73X6ZK
# 246  7Zt2KUh5mkpEpPGcNcFy51aGkh9Ycb5ELcqRH1n2GmAe
# 247  CK7UwtyYTo4CmBohCF9RhF6mCNDxnLMcZsCqouP9pump
# 248  J4fQTRN13MKpXhVE74t99msKJLbrjegjEgLBnzEv2YH1
#
# [249 rows x 3 columns]

# %%
df.to_csv('solana_meme_coins.csv', index=False)

# %%
combined_prices_df = pd.DataFrame()

all_prices = []
errors = []

# Create a list of already processed tokens if combined_prices_df exists
processed_tokens = []
if 'combined_prices_df' in locals():
    processed_tokens = combined_prices_df['Contract Address'].unique().tolist()

for token_address in df['Contract Address'].dropna():
    
    # Skip if already processed successfully
    if token_address in processed_tokens:
        continue
    print(token_address)
        
    try:
        price_df = get_token_price_history(token_address, start_date='2022-10-01', end_date='2024-11-01', interval='15m')
        
        if price_df is None:
            coin_name = df[df['Contract Address'] == token_address]['Coin'].iloc[0]
            errors.append({
                'Contract Address': token_address,
                'Coin': coin_name,
                'Error': 'No data returned'
            })
            continue
            
        price_df['Contract Address'] = token_address
        coin_name = df[df['Contract Address'] == token_address]['Coin'].iloc[0]
        price_df['Coin'] = coin_name
        all_prices.append(price_df)
        price_df.set_index('Time')['Close'].plot()
        
    except KeyError as e:
        coin_name = df[df['Contract Address'] == token_address]['Coin'].iloc[0]
        errors.append({
            'Contract Address': token_address,
            'Coin': coin_name,
            'Error': f'KeyError: {str(e)}'
        })
        time.sleep(2)
        continue
    time.sleep(2)

# Create errors dataframe
errors_df = pd.DataFrame(errors)

# Combine all price histories into one dataframe
if all_prices:
    combined_prices_df = pd.concat([combined_prices_df, pd.concat(all_prices, axis=0)])
combined_prices_df = pd.concat([combined_prices_df, pd.concat(all_prices, axis=0)])
combined_prices_df.to_csv('solana_meme_coins_prices.csv', index=False)
# Out:
# 9HGziACBczM3VorD3B6ZYtj6BA595jq8erzsSVtUNo6N
# HeLp6NuQkmYB4pYWo2zYs22mESHXPQYzXbB8n4V98jwC
# 6yjNqPzTSanBWSa6dxVEgTjePXBrZ2FoHLDQwYwEsyM6
# ABDoiSudvFjjJ25rtXn8V2b6QGrH59KN6thAbsPvpump
# AujTJJ7aMS8LDo3bFzoyXDwT3jBALUbu4VZhzZdTZLmG
# 2FuP7DR7VT5EobzarajGZHCqU5xXoEMbY2XmXoBSqk9M
# U237C8hKyZYL42TEtTv6JGtdwDr3pZaQeeWMCVVpump
# BNeaFbk7DRjMr1UhGuchRGMKvk2Z5bU9W8sNpn7Wvr9Y
# 9fEXUmPnDJYAXpoZ9nWi1gQZPwzVKdf8g9fYXW6Epump
# DoGinuF39MGaxJDeJ3QDk4qd2vXwkYf5TDYpkdpYjip
